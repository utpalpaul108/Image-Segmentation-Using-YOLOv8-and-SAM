# %% [markdown]
# ### Yolov8 Object Detection Model Training

# %%
import os

# %%
os.chdir('../')

# %%
# %pwd
# Out:
# '/home/utpal108/dev/Upwork/Projects/Image-Segmentation-Model-Using-YOLOv8-and-SAM'

# %%
from ultralytics import YOLO

# %% [markdown]
# #### Custom Training

# %%
model = YOLO("yolov8x.pt")
model.train(data="data.yaml", epochs=3, imgsz=640)
# Out:
# Ultralytics YOLOv8.2.9 🚀 Python-3.8.19 torch-2.3.0+cu121 CPU (AMD Ryzen 7 5700U with Radeon Graphics)
# ...
